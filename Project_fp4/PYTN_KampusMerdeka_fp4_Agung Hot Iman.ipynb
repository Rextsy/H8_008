# %% [markdown]
# ## Introduction
# Dataset "Credit Card Dataset for Clustering" dapat digunakan untuk mengembangkan model segmentasi pelanggan untuk membantu dalam menentukan strategi pemasaran. Dataset tersebut bersumber dari Kaggle dan berisi 9000 baris data serta 18 kolom data dari pengguna kartu kredit selama 6 bulan.

# %% [markdown]
# ## Import Libraries
# Import library-library yang dibutuhkan untuk komputasi, struktur data, visualisasi, dan modelling data.

# %%
# %pip install numpy pandas matplotlib seaborn scikit-learn pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: numpy in c:\users\agung\anaconda3\lib\site-packages (1.21.5)
# Requirement already satisfied: pandas in c:\users\agung\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\agung\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: seaborn in c:\users\agung\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: scikit-learn in c:\users\agung\anaconda3\lib\site-packages (1.0.2)
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import pickle

# %% [markdown]
# ## Data Loading
# Load dataset ke dalam Pandas dataframe.

# %%
df = pd.read_csv('CC GENERAL.csv') 
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %% [markdown]
# ## Data Exploration - 1
# Cek jumlah baris dan kolom padaset.

# %%
df.shape
# Out:
# (8950, 18)

# %% [markdown]
# Diketahui terdapat 299 baris dan 13 kolom pada dataset.
#
# Cek measures of central tendency dari dataset, seperti mean, median, dan modus.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %% [markdown]
# Cek nilai kosong/missing values pada dataset.

# %%
df.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# Diketahui terdapat 1 missing value pada kolom CREDIT_LIMIT dan 313 missing values pada kolom MINIMUM_PAYMENTS.

# %% [markdown]
# ## Data Cleaning
# Hapus kolom CUST_ID karena nilai datanya berupa nomor ID sehingga tidak relevan.

# %%
df.drop(['CUST_ID'], axis=1, inplace=True)

# %% [markdown]
# Hapus missing value pada kolom CREDIT_LIMIT.

# %%
df.dropna(subset=['CREDIT_LIMIT'], inplace=True)

# %% [markdown]
# Sedangkan untuk kolom MINIMUM_PAYMENTS, isi missing values dengan nilai median data dari kolom tersebut.

# %%
df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].median(), inplace=True)

# %% [markdown]
# ## Data Exploration - 2
# Cek measures of central tendency dari dataset, seperti mean, median, dan modus.

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8949.000000        8949.000000   8949.000000       8949.000000
# mean    1564.647593           0.877350   1003.316936        592.503572
# std     2081.584016           0.236798   2136.727848       1659.968851
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.365782           0.888889     39.800000          0.000000
# 50%      873.680279           1.000000    361.490000         38.000000
# 75%     2054.372848           1.000000   1110.170000        577.830000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8949.000000   8949.000000          8949.000000
# mean               411.113579    978.959616             0.490405
# std                904.378205   2097.264344             0.401360
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.650000   1113.868654             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8949.000000                       8949.000000
# mean                     0.202480                          0.364478
# std                      0.298345                          0.397451
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8949.000000       8949.000000    8949.000000   8949.000000
# mean                 0.135141          3.249078      14.711476   4494.449450
# std                  0.200132          6.824987      24.858552   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8949.000000       8949.000000       8949.000000  8949.000000
# mean    1733.336511        845.003358          0.153732    11.517935
# std     2895.168146       2332.905284          0.292511     1.337134
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.282850        170.875613          0.000000    12.000000
# 50%      857.062706        312.452292          0.000000    12.000000
# 75%     1901.279320        788.721609          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %% [markdown]
# Cek distribution dan variability dari kolom-kolom dataset dengan histogram.

# %%
plt.figure(figsize=(16,12))
for i, col in enumerate(df.columns, 1):
  plt.subplot(6, 3, i)
  sns.histplot(df[col], kde=True)
  plt.tight_layout()
plt.show()

# %% [markdown]
# Diketahui semua kolom kecuali kolom PURCHASE_FREQUENCY memiliki distribution miring/skew.
#
# Cek korelasi data antara kolom feature dan kolom target (DEATH EVENT) dengan heatmap.

# %%
plt.figure(figsize=(16,12))
sns.heatmap(df.corr(), annot=True, cmap='vlag', center=0)
plt.show()

# %% [markdown]
# ## Data Processing
# Lakukan standardization untuk dataset.

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)
X_scaled = pd.DataFrame(X_scaled, columns=df.columns)

X_scaled.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count  8.949000e+03       8.949000e+03  8.949000e+03      8.949000e+03
# mean   5.156601e-16      -7.789463e-15 -2.110948e-15     -3.777680e-15
# std    1.000056e+00       1.000056e+00  1.000056e+00      1.000056e+00
# min   -7.517040e-01      -3.705263e+00 -4.695839e-01     -3.569565e-01
# 25%   -6.900332e-01       4.873144e-02 -4.509562e-01     -3.569565e-01
# 50%   -3.319616e-01       5.179802e-01 -3.003952e-01     -3.340632e-01
# 75%    2.352788e-01       5.179802e-01  5.001060e-02     -8.840161e-03
# max    8.397195e+00       5.179802e-01  2.248248e+01      2.419985e+01
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count            8.949000e+03  8.949000e+03         8.949000e+03
# mean             6.572386e-16  1.274902e-15        -5.085514e-16
# std              1.000056e+00  1.000056e+00         1.000056e+00
# min             -4.546069e-01 -4.668054e-01        -1.221928e+00
# 25%             -4.546069e-01 -4.668054e-01        -1.014290e+00
# 50%             -3.561912e-01 -4.668054e-01         2.390672e-02
# 75%              6.362342e-02  6.432979e-02         1.062103e+00
# max              2.442576e+01  2.201002e+01         1.269742e+00
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                8.949000e+03                      8.949000e+03
# mean                 1.090520e-14                      2.254191e-16
# std                  1.000056e+00                      1.000056e+00
# min                 -6.787162e-01                     -9.170895e-01
# 25%                 -6.787162e-01                     -9.170895e-01
# 50%                 -3.993831e-01                     -4.977267e-01
# 75%                  3.268871e-01                      9.700395e-01
# max                  2.673295e+00                      1.599083e+00
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count            8.949000e+03      8.949000e+03   8.949000e+03  8.949000e+03
# mean             9.593647e-17      7.993258e-16  -2.122376e-16 -7.897483e-16
# std              1.000056e+00      1.000056e+00   1.000056e+00  1.000056e+00
# min             -6.752945e-01     -4.760829e-01  -5.918405e-01 -1.221468e+00
# 25%             -6.752945e-01     -4.760829e-01  -5.516107e-01 -7.954817e-01
# 50%             -6.752945e-01     -4.760829e-01  -3.102316e-01 -4.107196e-01
# 75%              4.351431e-01      1.100315e-01   9.206698e-02  5.511855e-01
# max              6.820167e+00      1.754694e+01   1.381045e+01  7.009692e+00
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT        TENURE
# count  8.949000e+03      8.949000e+03      8.949000e+03  8.949000e+03
# mean   7.491679e-16      1.541522e-16      1.583082e-15  6.247321e-15
# std    1.000056e+00      1.000056e+00      1.000056e+00  1.000056e+00
# min   -5.987332e-01     -3.622228e-01     -5.255884e-01 -4.126919e+00
# 25%   -4.663388e-01     -2.889810e-01     -5.255884e-01  3.605413e-01
# 50%   -3.026846e-01     -2.282908e-01     -5.255884e-01  3.605413e-01
# 75%    5.801121e-02     -2.412652e-02     -3.717957e-02  3.605413e-01
# max    1.692160e+01      3.239112e+01      2.893277e+00  3.605413e-01

# %% [markdown]
# Cek dataset yang telah ter-standardized dengan box plot.

# %%
plt.figure(figsize=(16,12))
sns.boxenplot(X_scaled)
plt.show()
# Out:
# c:\Users\Agung\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Tugas kuliah\Semester 7\MBKM\H8_008-1\Project_fp4\“PYTN_KampusMerdeka_fp4_Agung Hot Iman.ipynb Cell 29 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Tugas%20kuliah/Semester%207/MBKM/H8_008-1/Project_fp4/%E2%80%9CPYTN_KampusMerdeka_fp4_Agung%20Hot%20Iman.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(16,12))
# ----> <a href='vscode-notebook-cell:/d%3A/Tugas%20kuliah/Semester%207/MBKM/H8_008-1/Project_fp4/%E2%80%9CPYTN_KampusMerdeka_fp4_Agung%20Hot%20Iman.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> sns.boxenplot(X_scaled)
#       <a href='vscode-notebook-cell:/d%3A/Tugas%20kuliah/Semester%207/MBKM/H8_008-1/Project_fp4/%E2%80%9CPYTN_KampusMerdeka_fp4_Agung%20Hot%20Iman.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> plt.show()
#
# File c:\Users\Agung\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File c:\Users\Agung\anaconda3\lib\site-packages\seaborn\categorical.py:2634, in boxenplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, k_depth, linewidth, scale, outlier_prop, trust_alpha, showfliers, ax, **kwargs)
#    2622 @_deprecate_positional_args
#    2623 def boxenplot(
#    2624     *,
#    (...)
#    2631     ax=None, **kwargs
#    2632 ):
# -> 2634     plotter = _LVPlotter(x, y, hue, data, order, hue_order,
#    2635                          orient, color, palette, saturation,
#    2636                          width, dodge, k_depth, linewidth, scale,
#    2637                          outlier_prop, trust_alpha, showfliers)
#    2639     if ax is None:
#    2640         ax = plt.gca()
#
# File c:\Users\Agung\anaconda3\lib\site-packages\seaborn\categorical.py:1838, in _LVPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, k_depth, linewidth, scale, outlier_prop, trust_alpha, showfliers)
#    1834 self.trust_alpha = trust_alpha
#    1836 self.showfliers = showfliers
# -> 1838 self.establish_variables(x, y, hue, data, orient, order, hue_order)
#    1839 self.establish_colors(color, palette, saturation)
#
# File c:\Users\Agung\anaconda3\lib\site-packages\seaborn\categorical.py:156, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153         raise ValueError(err)
#     155 # Figure out the plotting orientation
# --> 156 orient = infer_orient(
#     157     x, y, orient, require_numeric=self.require_numeric
#     158 )
#     160 # Option 2a:
#     161 # We are plotting a single set of data
#     162 # ------------------------------------
#     163 if x is None or y is None:
#     164
#     165     # Determine where the data are
#
# File c:\Users\Agung\anaconda3\lib\site-packages\seaborn\_core.py:1311, in infer_orient(x, y, orient, require_numeric)
#    1283 def infer_orient(x=None, y=None, orient=None, require_numeric=True):
#    1284     """Determine how the plot should be oriented based on the data.
#    1285
#    1286     For historical reasons, the convention is to call a plot "horizontally"
#    (...)
#    1308
#    1309     """
# -> 1311     x_type = None if x is None else variable_type(x)
#    1312     y_type = None if y is None else variable_type(y)
#    1314     nonnumeric_dv_error = "{} orientation requires numeric `{}` variable."
#
# File c:\Users\Agung\anaconda3\lib\site-packages\seaborn\_core.py:1229, in variable_type(vector, boolean_type)
#    1226     return "categorical"
#    1228 # Special-case all-na data, which is always "numeric"
# -> 1229 if pd.isna(vector).all():
#    1230     return "numeric"
#    1232 # Special-case binary/boolean data, allow caller to determine
#    1233 # This triggers a numpy warning when vector has strings/objects
#    1234 # https://github.com/numpy/numpy/issues/6784
#    (...)
#    1238 # https://github.com/numpy/numpy/issues/13548
#    1239 # This is considered a bug by numpy and will likely go away.
#
# File c:\Users\Agung\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### KMeans
# Lakukan training untuk model KMeans dengan data dari model PCA sebelumnya. Lakukan training dengan jumlah cluster 1 sampai 10, lalu tampilkan plot inertia dari setiap hasil model KMeans yang di-train untuk dilakukan pengecekan Elbow Method.

# %%
kmeans_models = [KMeans(n_clusters=k).fit(X_scaled) for k in range(1, 10)]
inertias = [kmeans.inertia_ for kmeans in kmeans_models]

plt.plot(range(1, 10), inertias, 'bx-')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# Dari pengecekan Elbow Method, diketahui siku/elbow dari plot inertia diatas tidak terlalu dapat dipastikan tetapi untuk yang paling mendekati seperti siku adalah di cluster ke-2. Dengan demikian, ada kemungkinan jumlah cluster terbaik yang dapat diterapkan untuk dataset adalah 2.
#
# Agar lebih dapat memastikan jumlah cluster terbaik untuk dataset, lakukan pengecekan kembali dengan menampilkan plot Silhouette Scores dari setiap cluster.

# %%
elbow_start = 2
elbow_end = 5
ss = [silhouette_score(X_scaled, kmeans.labels_) for kmeans in kmeans_models[elbow_start:elbow_end]]

plt.plot(range(elbow_start, elbow_end), ss, 'bo-')
plt.xticks(range(elbow_start, elbow_end))
plt.title('Silhouette Scores vs Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Scores')
plt.show()

# %% [markdown]
# Diketahui cluster ke-2 memiliki Silhoutte Score paling tinggi. Dengan demikian, jumlah cluster terbaik yang dapat diterapkan untuk dataset adalah 2.
#
# Lakukan kembali training untuk model KMeans dengan jumlah cluster 2.

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X_scaled)

print('Silhoutte score of the model is ' + str(silhouette_score(X_scaled, kmeans.labels_)))
# Out:
# Silhoutte score of the model is 0.21033115271782984

# %% [markdown]
# Dapatkan cluster-cluster yang terdefinisikan.

# %%
clusters = kmeans.labels_
clusters
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %% [markdown]
# Untuk membantu menginterpretasikan setiap cluster, buat fuction untuk mengecek rule dari setiap cluster.

# %%
from IPython.display import display, HTML
from sklearn.tree import _tree, DecisionTreeClassifier

def pretty_print(df):
  return display( HTML( df.to_html().replace("\\n",
  " ") ) )

def get_class_rules(tree: DecisionTreeClassifier, feature_names: list):
  inner_tree: _tree.Tree = tree.tree_
  classes = tree.classes_
  class_rules_dict = dict()

  def tree_dfs(node_id=0, current_rule=[]):
    # feature[i] holds the feature to split on, for the internal node i.
    split_feature = inner_tree.feature[node_id]
    if split_feature != _tree.TREE_UNDEFINED: # internal node
      name = feature_names[split_feature]
      threshold = inner_tree.threshold[node_id]
      # left child
      left_rule = current_rule + ["({} <= {})".format(name, threshold)]
      tree_dfs(inner_tree.children_left[node_id], left_rule)
      # right child
      right_rule = current_rule + ["({} > {})".format(name, threshold)]
      tree_dfs(inner_tree.children_right[node_id], right_rule)
    else: # leaf
      dist = inner_tree.value[node_id][0]
      dist = dist/dist.sum()
      max_idx = dist.argmax()
      if len(current_rule) == 0:
        rule_string = "ALL"
      else:
        rule_string = " and ".join(current_rule)
      # register new rule to dictionary
      selected_class = classes[max_idx]
      class_probability = dist[max_idx]
      class_rules = class_rules_dict.get(selected_class, [])
      class_rules.append((rule_string, class_probability))
      class_rules_dict[selected_class] = class_rules
    
  tree_dfs() # start from root, node_id = 0
  return class_rules_dict

def cluster_report(data: pd.DataFrame, clusters, min_samples_leaf=50, pruning_level=0.01):
    # Create Model
    tree = DecisionTreeClassifier(min_samples_leaf=min_samples_leaf, ccp_alpha=pruning_level)
    tree.fit(data, clusters)
    
    # Generate Report
    feature_names = data.columns
    class_rule_dict = get_class_rules(tree, feature_names)

    report_class_list = []
    for class_name in class_rule_dict.keys():
        rule_list = class_rule_dict[class_name]
        combined_string = ""
        for rule in rule_list:
            combined_string += "[{}] {}\n\n".format(rule[1], rule[0])
        report_class_list.append((class_name, combined_string))
        
    cluster_instance_df = pd.Series(clusters).value_counts().reset_index()
    cluster_instance_df.columns = ['class_name', 'instance_count']
    report_df = pd.DataFrame(report_class_list, columns=['class_name', 'rule_list'])
    report_df = pd.merge(cluster_instance_df, report_df, on='class_name', how='left')
    pretty_print(report_df.sort_values(by='class_name')[['class_name', 'instance_count', 'rule_list']])

# %% [markdown]
# Cek rule dari setiap cluster.

# %%
cluster_report(df, clusters, min_samples_leaf=10, pruning_level=0.05)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>5257</td>
#       <td>[0.9577220077220078] (PURCHASES_FREQUENCY &lt;= 0.6306819915771484)  </td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>3692</td>
#       <td>[0.9214645794640488] (PURCHASES_FREQUENCY &gt; 0.6306819915771484)  </td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Diketahui cluster-cluster sebelumnya dapat diinterpretasikan sebagai berikut:
#
# * Cluster 0: Pengguna kartu kredit dengan pembelian tinggi.
# * Cluster 1: Pengguna kartu kredit dengan pembelian rendah.

# %% [markdown]
# ## Principal Component Analysis (PCA)
# Lakukan training untuk model PCA dengan dataset sebelumnya. Lakukan dengan jumlah PC 2 untuk mengubah dataset menjadi 2D dan dapat divisualisasikan.

# %%
pca = PCA(2)
pc = pca.fit_transform(df)

pc_df = pd.DataFrame(pc, columns=[f'PC{i}' for i in range(1, len(pc[0])+1)])
pc_df['CLUSTER'] = clusters

pc_df.head()
# Out:
#            PC1          PC2  CLUSTER
# 0 -4324.351008   915.734333        0
# 1  4120.975546 -2437.938847        0
# 2  1498.994555 -2001.750670        1
# 3  1321.563972 -1387.728898        0
# 4 -3741.083696   751.701480        0

# %% [markdown]
# Cek distribusi cluster data berdasarkan 2 kolom PC yang telah terdefinisikan dengan plot scatter.

# %%
legend_map = {0: 'Pengguna kartu kredit dengan pembelian tinggi', 
              1: 'Pengguna kartu kredit dengan pembelian rendah',}

plt.figure(figsize=(16, 12))
sns.scatterplot(data=pc_df, x='PC1', y='PC2', hue=pc_df['CLUSTER'].map(legend_map), palette='Set1')
plt.show()

# %% [markdown]
# ## Export Model
# Export model yang dipilih sebelumnya dengan menyimpannya menjadi file Pickle.

# %%
with open('cc_users_clusterer.pkl', 'wb') as file:
    pickle.dump(kmeans, file)

# %%
# !mkdir ./app/models
# !mv cc_users_clusterer.pkl ./app/models/cc_users_clusterer.pkl
# Out:
# The syntax of the command is incorrect.
# 'mv' is not recognized as an internal or external command,
# operable program or batch file.
