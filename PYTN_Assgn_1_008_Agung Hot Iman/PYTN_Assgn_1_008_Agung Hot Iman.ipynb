# %% [markdown]
# Nama Program : Introduction to Python for Data Science Batch : KS-008
#
# Nama : Agung Hot Iman No. Peserta : PYTN-KS08-008

# %% [markdown]
# ## Pandas
#
# ### Using the Pandas Python Library

# %%
# Mengimpor pustaka yang dibutuhkan

import numpy as np # useful for many scientific computing in python
import pandas as pd # primary data structure library

# %%
# Membaca data dan menyimpan ke DataFrame

df_lon = pd.read_csv('london_crime_by_lsoa.csv')

print('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
df_lon.shape # Melihat berapa banyak data
# Out:
# (13490604, 7)

# %%
# mengonfigurasi pandas untuk menampilkan semua kolom

pd.set_option("display.max.columns", None)

# %%
# pandas config precision 2 digit decimal

pd.set_option("display.precision", 2)

# %%
# Karena datanya terlalu banyak, maka saya gunakan 20.000 data pertama saja menggunakan fungsi .iloc

df_london = df_lon.iloc[:20000]

# %%
# Tampilkan lima baris dataset teratas

print(df_london.head())
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
# Melihat 5 data terakhir

df_london.tail()
# Out:
#        lsoa_code    borough      major_category               minor_category  \
# 19995  E01001369     Ealing             Robbery            Personal Property
# 19996  E01003134    Lambeth  Theft and Handling  Theft/Taking of Pedal Cycle
# 19997  E01004014  Southwark     Criminal Damage  Criminal Damage To Dwelling
# 19998  E01003532     Newham             Robbery            Personal Property
# 19999  E01003516     Newham            Burglary  Burglary in Other Buildings
#
#        value  year  month
# 19995      0  2014      4
# 19996      0  2008      7
# 19997      0  2014      7
# 19998      0  2015     11
# 19999      0  2010      5

# %% [markdown]
# ### Displaying Data Types

# %%
# Mendapatkan informasi dasar tentang kerangka data

df_london.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   lsoa_code       20000 non-null  object
#  1   borough         20000 non-null  object
#  2   major_category  20000 non-null  object
#  3   minor_category  20000 non-null  object
#  4   value           20000 non-null  int64
#  5   year            20000 non-null  int64
#  6   month           20000 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB

# %%
# Melihat ringkasan singkat dari setiap kolom

df_london.describe()
# Out:
#           value      year     month
# count  20000.00  20000.00  20000.00
# mean       0.48   2011.97      6.49
# std        1.66      2.58      3.45
# min        0.00   2008.00      1.00
# 25%        0.00   2010.00      4.00
# 50%        0.00   2012.00      6.00
# 75%        1.00   2014.00      9.00
# max       80.00   2016.00     12.00

# %%
# Menampilkan quantile 25 atau 25% percentile

df_london.quantile(.25)
# Out:
# value       0.0
# year     2010.0
# month       4.0
# Name: 0.25, dtype: float64

# %%
# Menampilkan quantile 50 atau 50% percentile

df_london.quantile(.50)
# Out:
# value       0.0
# year     2012.0
# month       6.0
# Name: 0.5, dtype: float64

# %%
# Menampilkan quantile 75 atau 75% percentile

df_london.quantile(.75)
# Out:
# value       1.0
# year     2014.0
# month       9.0
# Name: 0.75, dtype: float64

# %% [markdown]
# ### Exploring Dataset

# %%
# Menghitung jumlah kejadian kriminal berdasarkan area kepolisian

df_london["lsoa_code"].value_counts()
# Out:
# E01004128    13
# E01004601    13
# E01004376    12
# E01004292    12
# E01003492    12
#              ..
# E01001843     1
# E01002190     1
# E01001004     1
# E01001850     1
# E01004160     1
# Name: lsoa_code, Length: 4731, dtype: int64

# %%
# Menghitung jumlah kejadian kriminal berdasarkan wilayah london yang statistiknya terkait

df_london["borough"].value_counts()
# Out:
# Barnet                    869
# Croydon                   850
# Ealing                    803
# Enfield                   785
# Lambeth                   779
# Southwark                 758
# Bromley                   754
# Wandsworth                731
# Brent                     731
# Newham                    712
# Lewisham                  711
# Hillingdon                672
# Redbridge                 646
# Haringey                  622
# Greenwich                 613
# Hackney                   612
# Waltham Forest            609
# Havering                  598
# Tower Hamlets             592
# Westminster               585
# Hounslow                  561
# Harrow                    553
# Camden                    540
# Bexley                    539
# Islington                 533
# Sutton                    505
# Merton                    494
# Barking and Dagenham      487
# Kensington and Chelsea    470
# Richmond upon Thames      453
# Hammersmith and Fulham    442
# Kingston upon Thames      378
# City of London             13
# Name: borough, dtype: int64

# %%
# Menghitung jumlah kejadian kriminal berdasarkan kategori utamanya

df_london["major_category"].value_counts()
# Out:
# Theft and Handling             5871
# Violence Against the Person    4736
# Criminal Damage                2979
# Drugs                          1807
# Burglary                       1566
# Robbery                        1399
# Other Notifiable Offences      1149
# Fraud or Forgery                344
# Sexual Offences                 149
# Name: major_category, dtype: int64

# %%
# Menghitung jumlah kejadian kriminal berdasarkan sub-kategorinya

df_london["minor_category"].value_counts()
# Out:
# Possession Of Drugs                       819
# Assault with Injury                       817
# Harassment                                810
# Theft/Taking of Pedal Cycle               807
# Burglary in a Dwelling                    804
# Other Notifiable                          784
# Wounding/GBH                              782
# Common Assault                            777
# Theft/Taking Of Motor Vehicle             774
# Other Theft                               770
# Other Criminal Damage                     765
# Personal Property                         764
# Burglary in Other Buildings               762
# Motor Vehicle Interference & Tampering    760
# Other Theft Person                        758
# Criminal Damage To Dwelling               749
# Drug Trafficking                          746
# Other violence                            743
# Criminal Damage To Other Building         741
# Criminal Damage To Motor Vehicle          724
# Theft From Motor Vehicle                  714
# Offensive Weapon                          686
# Handling Stolen Goods                     647
# Theft From Shops                          641
# Business Property                         635
# Going Equipped                            365
# Other Drugs                               242
# Counted per Victim                        196
# Other Fraud & Forgery                     148
# Murder                                    121
# Other Sexual                              110
# Rape                                       39
# Name: minor_category, dtype: int64

# %%
# Menghitung jumlah kejadian kriminal berdasarkan tahun

df_london["year"].value_counts()
# Out:
# 2010    2280
# 2009    2276
# 2016    2234
# 2012    2234
# 2008    2231
# 2011    2221
# 2013    2210
# 2014    2164
# 2015    2150
# Name: year, dtype: int64

# %%
# Menghitung jumlah kejadian kriminal berdasarkan bulan

df_london["month"].value_counts()
# Out:
# 5     1730
# 4     1713
# 12    1691
# 3     1690
# 9     1689
# 8     1668
# 2     1653
# 10    1644
# 7     1638
# 1     1637
# 6     1627
# 11    1620
# Name: month, dtype: int64

# %%
# Menampilkan jumlah kejadian kriminal yang terjadi di wilayah Croydon berdasarkan major_category

df_london.loc[df_london["borough"] == "Croydon", "major_category"].value_counts()
# Out:
# Theft and Handling             248
# Violence Against the Person    196
# Criminal Damage                120
# Drugs                           82
# Burglary                        81
# Robbery                         72
# Other Notifiable Offences       38
# Fraud or Forgery                 9
# Sexual Offences                  4
# Name: major_category, dtype: int64

# %%
# Menampilkan tahun kejadian kriminal narkoba pertama pada dataframe

df_london.loc[df_london["major_category"] == "Drugs", "year"].min()
# Out:
# 2008

# %%
# Menampilkan tahun kejadian kriminal narkoba terakhir pada dataframe

df_london.loc[df_london["major_category"] == "Drugs", "year"].max()
# Out:
# 2016

# %%
# Menampilkan tahun pertama dan terakhir kejadian kriminal pemerkosaan pada dataframe

df_london.loc[df_london["minor_category"] == "Rape", "year"].agg(("min", "max"))
# Out:
# min    2008
# max    2016
# Name: year, dtype: int64

# %%
# Menjumlahkan total kejadian kriminal narkoba

df_london.loc[df_london["major_category"] == "Drugs", "value"].sum()
# Out:
# 874

# %%
# Melihat tahun pertama pada dataframe

df_london['year'].min()
# Out:
# 2008

# %%
# Melihat tahun terakhir pada dataframe

df_london['year'].max()
# Out:
# 2016

# %%
# Mendapatkan list header kolom

df_london.columns.values
# Out:
# array(['lsoa_code', 'borough', 'major_category', 'minor_category',
#        'value', 'year', 'month'], dtype=object)

# %%
# Mendapatkan daftar indeks

df_london.index.values
# Out:
# array([    0,     1,     2, ..., 19997, 19998, 19999], dtype=int64)

# %%
# Melihat dimensi dataframe

df_london.shape
# Out:
# (20000, 7)

# %% [markdown]
# ### Querying Dataset

# %%
# Melihat dataframe

df_london
# Out:
#        lsoa_code     borough               major_category  \
# 0      E01001116     Croydon                     Burglary
# 1      E01001646   Greenwich  Violence Against the Person
# 2      E01000677     Bromley  Violence Against the Person
# 3      E01003774   Redbridge                     Burglary
# 4      E01004563  Wandsworth                      Robbery
# ...          ...         ...                          ...
# 19995  E01001369      Ealing                      Robbery
# 19996  E01003134     Lambeth           Theft and Handling
# 19997  E01004014   Southwark              Criminal Damage
# 19998  E01003532      Newham                      Robbery
# 19999  E01003516      Newham                     Burglary
#
#                     minor_category  value  year  month
# 0      Burglary in Other Buildings      0  2016     11
# 1                   Other violence      0  2016     11
# 2                   Other violence      0  2015      5
# 3      Burglary in Other Buildings      0  2016      3
# 4                Personal Property      0  2008      6
# ...                            ...    ...   ...    ...
# 19995            Personal Property      0  2014      4
# 19996  Theft/Taking of Pedal Cycle      0  2008      7
# 19997  Criminal Damage To Dwelling      0  2014      7
# 19998            Personal Property      0  2015     11
# 19999  Burglary in Other Buildings      0  2010      5
#
# [20000 rows x 7 columns]

# %%
# Melihat kejadian kriminal pada tahun 2016 di dalam dataframe

current_crime = df_london[df_london["year"] == 2016]
current_crime
# Out:
#        lsoa_code                 borough               major_category  \
# 0      E01001116                 Croydon                     Burglary
# 1      E01001646               Greenwich  Violence Against the Person
# 3      E01003774               Redbridge                     Burglary
# 9      E01004177                  Sutton           Theft and Handling
# 14     E01002398              Hillingdon           Theft and Handling
# ...          ...                     ...                          ...
# 19948  E01003449                  Merton              Criminal Damage
# 19951  E01004606              Wandsworth             Fraud or Forgery
# 19956  E01002857  Kensington and Chelsea                        Drugs
# 19965  E01000424                  Bexley           Theft and Handling
# 19982  E01032744                  Ealing  Violence Against the Person
#
#                       minor_category  value  year  month
# 0        Burglary in Other Buildings      0  2016     11
# 1                     Other violence      0  2016     11
# 3        Burglary in Other Buildings      0  2016      3
# 9        Theft/Taking of Pedal Cycle      1  2016      8
# 14     Theft/Taking Of Motor Vehicle      0  2016      2
# ...                              ...    ...   ...    ...
# 19948    Criminal Damage To Dwelling      0  2016     12
# 19951          Other Fraud & Forgery      0  2016     12
# 19956               Drug Trafficking      0  2016     12
# 19965             Other Theft Person      0  2016     12
# 19982            Assault with Injury      2  2016      9
#
# [2234 rows x 7 columns]

# %%
# Melihat dimensi current_crime

current_crime.shape
# Out:
# (2234, 7)

# %% [markdown]
# ### Grouping and Aggregating Data

# %%
# Menjumlahkan keseluruhan value pada dataframe

values = df_london["value"]
values.sum()
# Out:
# 9608

# %%
# mencetak 5 data teratas

df_london.head(5)
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
# menjumlahkan value tiap wilayah

df_london.groupby("borough", sort=False)["value"].sum()
# Out:
# borough
# Croydon                   481
# Greenwich                 261
# Bromley                   264
# Redbridge                 248
# Wandsworth                337
# Ealing                    326
# Hounslow                  239
# Newham                    385
# Sutton                    168
# Haringey                  348
# Lambeth                   489
# Richmond upon Thames      181
# Hillingdon                385
# Havering                  159
# Barking and Dagenham      244
# Kingston upon Thames       94
# Westminster               544
# Hackney                   332
# Enfield                   296
# Harrow                    183
# Lewisham                  323
# Brent                     309
# Southwark                 489
# Barnet                    307
# Waltham Forest            280
# Camden                    406
# Bexley                    172
# Kensington and Chelsea    268
# Islington                 349
# Tower Hamlets             342
# Hammersmith and Fulham    246
# Merton                    151
# City of London              2
# Name: value, dtype: int64

# %%
# menjumlahkan value tiap major_category

df_london.groupby("major_category", sort=False)["value"].sum()
# Out:
# major_category
# Burglary                       1171
# Violence Against the Person    2257
# Robbery                         386
# Theft and Handling             3863
# Criminal Damage                 884
# Drugs                           874
# Fraud or Forgery                  5
# Other Notifiable Offences       167
# Sexual Offences                   1
# Name: value, dtype: int64

# %%
# menjumlahkan value tiap minor_category

df_london.groupby("minor_category", sort=False)["value"].sum()
# Out:
# minor_category
# Burglary in Other Buildings                423
# Other violence                             112
# Personal Property                          346
# Other Theft                               1426
# Offensive Weapon                            65
# Criminal Damage To Other Building          110
# Theft/Taking of Pedal Cycle                299
# Motor Vehicle Interference & Tampering      83
# Theft/Taking Of Motor Vehicle              317
# Wounding/GBH                               178
# Other Theft Person                         368
# Common Assault                             589
# Theft From Shops                           551
# Possession Of Drugs                        818
# Harassment                                 677
# Handling Stolen Goods                       27
# Criminal Damage To Dwelling                213
# Burglary in a Dwelling                     748
# Criminal Damage To Motor Vehicle           337
# Other Criminal Damage                      224
# Counted per Victim                           5
# Going Equipped                               8
# Other Fraud & Forgery                        0
# Assault with Injury                        633
# Drug Trafficking                            53
# Other Drugs                                  3
# Business Property                           40
# Other Notifiable                           159
# Other Sexual                                 1
# Theft From Motor Vehicle                   792
# Rape                                         0
# Murder                                       3
# Name: value, dtype: int64

# %% [markdown]
# ### Specifying Data Types

# %%
# Hitung jumlah elemen yang berbeda dalam sumbu yang ditentukan.

df_london["lsoa_code"].nunique()
# Out:
# 4731

# %%
# Menghitung kejadian kriminal berdasarkan lsoa_code

df_london["lsoa_code"].value_counts()
# Out:
# E01004128    13
# E01004601    13
# E01004376    12
# E01004292    12
# E01003492    12
#              ..
# E01001843     1
# E01002190     1
# E01001004     1
# E01001850     1
# E01004160     1
# Name: lsoa_code, Length: 4731, dtype: int64

# %% [markdown]
# ### Missing Value

# %%
# Melihat kerangka data

df_london.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   lsoa_code       20000 non-null  object
#  1   borough         20000 non-null  object
#  2   major_category  20000 non-null  object
#  3   minor_category  20000 non-null  object
#  4   value           20000 non-null  int64
#  5   year            20000 non-null  int64
#  6   month           20000 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB

# %%
# Menghitung jumlah missing value

df_london.isna().sum()
# Out:
# lsoa_code         0
# borough           0
# major_category    0
# minor_category    0
# value             0
# year              0
# month             0
# dtype: int64

# %%
# Mengecek apakah terdapat missing value dalam dataframe

df_london.isnull().values.any()
# Out:
# False

# %%
# Mengecek apakah terdapat missing value dalam dataframe

print(df_london.isnull().any())
# Out:
# lsoa_code         False
# borough           False
# major_category    False
# minor_category    False
# value             False
# year              False
# month             False
# dtype: bool

# %% [markdown]
# ### Visualizing Pandas DataFrame

# %%
# Menggunakan pustaka matplotlib

# %matplotlib inline

# %%
# Mencetak dataframe

df_london
# Out:
#        lsoa_code     borough               major_category  \
# 0      E01001116     Croydon                     Burglary
# 1      E01001646   Greenwich  Violence Against the Person
# 2      E01000677     Bromley  Violence Against the Person
# 3      E01003774   Redbridge                     Burglary
# 4      E01004563  Wandsworth                      Robbery
# ...          ...         ...                          ...
# 19995  E01001369      Ealing                      Robbery
# 19996  E01003134     Lambeth           Theft and Handling
# 19997  E01004014   Southwark              Criminal Damage
# 19998  E01003532      Newham                      Robbery
# 19999  E01003516      Newham                     Burglary
#
#                     minor_category  value  year  month
# 0      Burglary in Other Buildings      0  2016     11
# 1                   Other violence      0  2016     11
# 2                   Other violence      0  2015      5
# 3      Burglary in Other Buildings      0  2016      3
# 4                Personal Property      0  2008      6
# ...                            ...    ...   ...    ...
# 19995            Personal Property      0  2014      4
# 19996  Theft/Taking of Pedal Cycle      0  2008      7
# 19997  Criminal Damage To Dwelling      0  2014      7
# 19998            Personal Property      0  2015     11
# 19999  Burglary in Other Buildings      0  2010      5
#
# [20000 rows x 7 columns]

# %%
# Memvisualisasikan jumlah kejadian kriminal Perampokan berdasarkan tahun dan value

df_london[df_london["major_category"] == "Robbery"].groupby("year")["value"].sum().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# Memvisualisasikan jumlah kejadian kriminal Perampokan berdasarkan tahun dan value

df_london[df_london["major_category"] == "Robbery"].groupby("year")["value"].sum()
# Out:
# year
# 2008    54
# 2009    45
# 2010    44
# 2011    51
# 2012    35
# 2013    60
# 2014    33
# 2015    30
# 2016    34
# Name: value, dtype: int64

# %%
# Memvisualisasikan jumlah kerjadian kriminal berdasarkan 10 major_category terbanyak 

df_london["major_category"].value_counts().head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# Memvisualisasikan jumlah kerjadian kriminal berdasarkan 10 major_category terbanyak

df_london["major_category"].value_counts().head(10)
# Out:
# Theft and Handling             5871
# Violence Against the Person    4736
# Criminal Damage                2979
# Drugs                          1807
# Burglary                       1566
# Robbery                        1399
# Other Notifiable Offences      1149
# Fraud or Forgery                344
# Sexual Offences                 149
# Name: major_category, dtype: int64

# %%
# Memvisualisasikan jumlah kerjadian kriminal berdasarkan 10 wilayah paling banyak

df_london["borough"].value_counts().head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# Memvisualisasikan jumlah kerjadian kriminal berdasarkan 10 wilayah paling banyak

df_london["borough"].value_counts().head(10)
# Out:
# Barnet        869
# Croydon       850
# Ealing        803
# Enfield       785
# Lambeth       779
# Southwark     758
# Bromley       754
# Wandsworth    731
# Brent         731
# Newham        712
# Name: borough, dtype: int64

# %%
# Memvisualisasikan jumlah kerjadian kriminal berdasarkan 10 wilayah paling sedikit

df_london["borough"].value_counts().tail(10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# Memvisualisasikan jumlah kerjadian kriminal berdasarkan 10 wilayah paling sedikit

df_london["borough"].value_counts().tail(10)
# Out:
# Bexley                    539
# Islington                 533
# Sutton                    505
# Merton                    494
# Barking and Dagenham      487
# Kensington and Chelsea    470
# Richmond upon Thames      453
# Hammersmith and Fulham    442
# Kingston upon Thames      378
# City of London             13
# Name: borough, dtype: int64

# %%
# Memvisualisasikan jumlah kerjadian kriminal di wilayah Wandsworth tahun 2011 keatas

Wandsworth_year_2011 = df_london[( df_london["borough"] == "Wandsworth") & (df_london['year']>2011)]

#.plot(kind='scater',x='value')
Wandsworth_year_2011
# Out:
#        lsoa_code     borough               major_category  \
# 278    E01004572  Wandsworth                        Drugs
# 286    E01004476  Wandsworth              Criminal Damage
# 342    E01004598  Wandsworth           Theft and Handling
# 372    E01004496  Wandsworth           Theft and Handling
# 410    E01004627  Wandsworth           Theft and Handling
# ...          ...         ...                          ...
# 19684  E01004512  Wandsworth  Violence Against the Person
# 19686  E01004601  Wandsworth  Violence Against the Person
# 19909  E01004629  Wandsworth  Violence Against the Person
# 19947  E01004475  Wandsworth              Sexual Offences
# 19951  E01004606  Wandsworth             Fraud or Forgery
#
#                     minor_category  value  year  month
# 278            Possession Of Drugs      0  2014      9
# 286    Criminal Damage To Dwelling      0  2016     12
# 342          Handling Stolen Goods      0  2016      2
# 372          Handling Stolen Goods      0  2012      8
# 410             Other Theft Person      1  2012      8
# ...                            ...    ...   ...    ...
# 19684               Common Assault      0  2015      7
# 19686                 Wounding/GBH      1  2014     10
# 19909               Common Assault      0  2012     12
# 19947                 Other Sexual      0  2015      3
# 19951        Other Fraud & Forgery      0  2016     12
#
# [401 rows x 7 columns]

# %%
# Mencetak visualisasi jumlah kerjadian kriminal di wilayah Wandsworth tahun 2011 keatas

Wandsworth_year_2011.plot(kind='scatter',x='year',y='value')
# Out:
# <AxesSubplot:xlabel='year', ylabel='value'>

# %%
# Mencetak visualisasi jumlah kerjadian kriminal di wilayah Camden sebelum tahun 2013 keatas

Camden_year_2013 = df_london[( df_london["borough"] == "Camden") & (df_london['year']<2013)]

#.plot(kind='scater',x='value')
Camden_year_2013
# Out:
#        lsoa_code borough               major_category  \
# 58     E01000893  Camden           Theft and Handling
# 135    E01000936  Camden                      Robbery
# 270    E01000961  Camden  Violence Against the Person
# 445    E01000868  Camden                        Drugs
# 484    E01000969  Camden              Criminal Damage
# ...          ...     ...                          ...
# 19873  E01000911  Camden  Violence Against the Person
# 19881  E01000904  Camden  Violence Against the Person
# 19908  E01000900  Camden                        Drugs
# 19955  E01000854  Camden    Other Notifiable Offences
# 19972  E01000882  Camden  Violence Against the Person
#
#                          minor_category  value  year  month
# 58        Theft/Taking Of Motor Vehicle      0  2012      9
# 135                   Personal Property      1  2011     11
# 270                          Harassment      1  2012     12
# 445                 Possession Of Drugs      0  2008     10
# 484    Criminal Damage To Motor Vehicle      1  2009      8
# ...                                 ...    ...   ...    ...
# 19873                        Harassment      0  2009      1
# 19881               Assault with Injury      2  2010      3
# 19908               Possession Of Drugs      0  2010      7
# 19955                  Other Notifiable      0  2008      1
# 19972               Assault with Injury      0  2012      9
#
# [299 rows x 7 columns]

# %%
Camden_year_2013.plot(kind='scatter',x='year',y='value')
# Out:
# <AxesSubplot:xlabel='year', ylabel='value'>

# %% [markdown]
# ### Filtering based on a criteria

# %%
# Menampilkan data kriminal (minor_category=personal property)

# 1. membuat kondisi boolean series
condition = df_london['minor_category'] == 'Personal Property'
print(condition)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 19995     True
# 19996    False
# 19997    False
# 19998     True
# 19999    False
# Name: minor_category, Length: 20000, dtype: bool

# %%
# pass kondisi kedalam dataframe

df_london[condition]
# Out:
#        lsoa_code               borough major_category     minor_category  \
# 4      E01004563            Wandsworth        Robbery  Personal Property
# 7      E01002633              Hounslow        Robbery  Personal Property
# 12     E01003852  Richmond upon Thames        Robbery  Personal Property
# 50     E01001206                Ealing        Robbery  Personal Property
# 66     E01000808               Bromley        Robbery  Personal Property
# ...          ...                   ...            ...                ...
# 19934  E01002397            Hillingdon        Robbery  Personal Property
# 19964  E01033724            Hillingdon        Robbery  Personal Property
# 19978  E01003969             Southwark        Robbery  Personal Property
# 19995  E01001369                Ealing        Robbery  Personal Property
# 19998  E01003532                Newham        Robbery  Personal Property
#
#        value  year  month
# 4          0  2008      6
# 7          0  2013      4
# 12         0  2014      1
# 50         0  2015      7
# 66         0  2014      6
# ...      ...   ...    ...
# 19934      7  2008     11
# 19964      0  2008      5
# 19978      0  2012      3
# 19995      0  2014      4
# 19998      0  2015     11
#
# [764 rows x 7 columns]

# %%
# kita dapat melewati beberapa kriteria di baris yang sama
# Filter berdasarkan major_category = Robbery and minor_category = Personal Property

df_london[(df_london['major_category'] == 'Robbery') & (df_london['minor_category'] == 'Personal Property')]
# Out:
#        lsoa_code               borough major_category     minor_category  \
# 4      E01004563            Wandsworth        Robbery  Personal Property
# 7      E01002633              Hounslow        Robbery  Personal Property
# 12     E01003852  Richmond upon Thames        Robbery  Personal Property
# 50     E01001206                Ealing        Robbery  Personal Property
# 66     E01000808               Bromley        Robbery  Personal Property
# ...          ...                   ...            ...                ...
# 19934  E01002397            Hillingdon        Robbery  Personal Property
# 19964  E01033724            Hillingdon        Robbery  Personal Property
# 19978  E01003969             Southwark        Robbery  Personal Property
# 19995  E01001369                Ealing        Robbery  Personal Property
# 19998  E01003532                Newham        Robbery  Personal Property
#
#        value  year  month
# 4          0  2008      6
# 7          0  2013      4
# 12         0  2014      1
# 50         0  2015      7
# 66         0  2014      6
# ...      ...   ...    ...
# 19934      7  2008     11
# 19964      0  2008      5
# 19978      0  2012      3
# 19995      0  2014      4
# 19998      0  2015     11
#
# [764 rows x 7 columns]

# %%
# tinjau perubahan yang telah kita buat pada kerangka data kita

print('data dimensions:', df_london.shape)
print(df_london.columns)
df_london.head(2)
# Out:
# data dimensions: (20000, 7)
# Index(['lsoa_code', 'borough', 'major_category', 'minor_category', 'value',
#        'year', 'month'],
#       dtype='object')
#    lsoa_code    borough               major_category  \
# 0  E01001116    Croydon                     Burglary
# 1  E01001646  Greenwich  Violence Against the Person
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11

# %% [markdown]
# ### Visualizing Data using Matplotlib

# %%
# Mengimpor pustaka yang dibutuhkan

# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Melihat versi pustaka matplotlib

print('Matplotlib version: ', mpl.__version__)
# Out:
# Matplotlib version:  3.5.1

# %%
# Menggunakan ggplot

print(plt.style.available)
mpl.style.use(['ggplot'])
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ### Line Plot

# %%
# Mendeklarasikan variabel years yang berisi tahun

years=df_london['year'].unique()

# %%
# Mendeklarasikan variabel sumsandyears yang berisi tahun yang dijumlahkan

sumsandyear=df_london.groupby('year').sum()

# %%
# Mendeklarasikan variabel sums berisi nilai value yang dikonversi ke numpy array

sums=sumsandyear['value'].to_numpy()

# %%
# Membuat fungsi perulanagan untuk mencetak tahun 2008 - 2016
n = len(years)

for i in range(n):
    for j in range(0, n-i-1):
        if years[j] > years[j+1] :
                years[j], years[j+1] = years[j+1], years[j]
                sums[j], sums[j+1] = sums[j+1], sums[j]
 
print("Tahun :  ")
print(years)
print("Jumlah kejadian kriminal yang terjadi di setiap tahun :")
print(sums)
# Out:
# Tahun :
# [2008 2009 2010 2011 2012 2013 2014 2015 2016]
# Jumlah kejadian kriminal yang terjadi di setiap tahun :
# [1084 1164 1070  982 1139 1046  934 1008 1181]

# %%
print("Grafik garis yang menunjukkan jumlah total kejahatan dalam tahun 2008 to 2016")

crime = np.arange(len(years))

plt.xticks(crime,years)
plt.plot(sums)
plt.xticks(crime,years)
plt.title("Kejadian Kriminal pada tahun 2008 sampai 2016 di London", color='red')
plt.xlabel('Tahun', color='red')
plt.ylabel("Banyak Kasus", color='red')
plt.xticks(rotation=-45 )
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xticks(color='red')
plt.yticks(color='red')
plt.show()
# Out:
# Grafik garis yang menunjukkan jumlah total kejahatan dalam tahun 2008 to 2016

# %%
# Memvisualisasikan jumlah kejadian kriminal Perampokan berdasarkan tahun dan value

Robbery = df_london[df_london["major_category"] == "Robbery"].groupby("year")["value"].sum()
Robbery.head()
# Out:
# year
# 2008    54
# 2009    45
# 2010    44
# 2011    51
# 2012    35
# Name: value, dtype: int64

# %%
# Mencetak visualisasi variabel Robbery

Robbery.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
Robbery.index = Robbery.index.map(int) # lets change the index values of Robbery to type integer for plotting
Robbery.plot(kind='line')

plt.title('Kejahatan Kriminal Perampokan di London')
plt.ylabel('Banyak Kasus')
plt.xlabel('Tahun')

plt.show() # need this line to show the updates made to the figure

# %%
# memberi anotasi lonjakan di plot dengan menggunakan metode plt.text()

Robbery.plot(kind='line')

plt.title('Kejahatan Kriminal Perampokan di London')
plt.ylabel('Banyak Kasus')
plt.xlabel('Tahun')

# memberikan anotasi pada lonjakan tahun 2012
# syntax : plt.text(x, y, label)
plt.text(2012, 45, 'Lonjakan 2013')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Memvisualisasikan jumlah kejadian kriminal Narkoba berdasarkan tahun dan value

Drugs = df_london[df_london["major_category"] == "Drugs"].groupby("year")["value"].sum()
Drugs.head()
# Out:
# year
# 2008    152
# 2009     87
# 2010    162
# 2011     98
# 2012     89
# Name: value, dtype: int64

# %%
Drugs.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# memberi anotasi lonjakan di plot dengan menggunakan metode plt.text()

Drugs.plot(kind='line')

plt.title('Kejahatan Kriminal Narkoba di London')
plt.ylabel('Banyak Kasus')
plt.xlabel('Tahun')

# memberikan anotasi pada lonjakan tahun 2010
# syntax : plt.text(x, y, label)
plt.text(2009, 120, 'Lonjakan 2010') # see note below

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Area Plot
#
# * Mengimplementasikan Area Plot Menggunakan Matplotlib Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik

# %%
# Mencetak kejadian kriminal 8 data pertama berdasarkan major category

df_london.major_category.head(8).value_counts().plot(kind='area', alpha=0.25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Informasi
#
# * Berdasarkan 8 data pertama, kejadian kriminal yang terjadi meliputi Violence Against the Person(3 Kasus), Burglary(2 Kasus), Robbery(2 Kasus), dan Theft and Handling(1 Kasus)

# %%
# Mencetak kejadian kriminal 10 data terakhir berdasarkan major category

df_london.major_category.tail(10).value_counts().plot(kind='area', alpha=0.25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Informasi
#
# * Berdasarkan 10 data terakhir, kejadian kriminal yang terjadi meliputi Violence Against the person (3 kasus), Roberry (3 kasus), Theft and Handling(2 Kasus), Criminal Damage(1 kasus), dan Burglary(1 Kasus)

# %% [markdown]
# ### Histogram
#
# * Mengimplementasikan Histogram Menggunakan Matplotlib Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik

# %%
plt.title('Major Category 10 Kejadian Kriminal Teratas')
plt.xlabel('Major Category')
plt.ylabel('Banyak Kasus')
plt.hist(df_london['major_category'].head(10), color='steelblue')
# Out:
# (array([2., 0., 3., 0., 0., 2., 0., 2., 0., 1.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Informasi
#
# * Berdasarkan 10 data pertama, kejadian kriminal yang terjadi meliputi Violence Against the Person(3 Kasus), Burglary(2 Kasus), Robbery(2 Kasus), Theft and Handling(2 Kasus), dan Criminal Damage(1 kasus)

# %%
plt.title('Major Category 10 Kejadian Kriminal Terbawah')
plt.xlabel('Major Category')
plt.ylabel('Banyak Kasus')
plt.hist(df_london['major_category'].tail(10), color='steelblue')
# Out:
# (array([3., 0., 2., 0., 0., 3., 0., 1., 0., 1.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Informasi
#
# * Berdasarkan 10 data terakhir, kejadian kriminal yang terjadi meliputi Violence Against the Person(3 Kasus), Robbery(3 Kasus), Theft and Handling(2 Kasus),Burglary(1 Kasus) dan Criminal Damage(1 kasus)

# %% [markdown]
# ### Bar Charts (Dataframe)
#
# * Mengimplementasikan Bar Chart Menggunakan Matplotlib Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik

# %% [markdown]
# ### Vertical bar plot

# %%
# Menghitung banyak kasus berdasrkan major_category pada dataframe london

df_london.major_category.value_counts()
# Out:
# Theft and Handling             5871
# Violence Against the Person    4736
# Criminal Damage                2979
# Drugs                          1807
# Burglary                       1566
# Robbery                        1399
# Other Notifiable Offences      1149
# Fraud or Forgery                344
# Sexual Offences                 149
# Name: major_category, dtype: int64

# %%
# Memvisualisasikan banyak kasus berdasrkan major_category pada dataframe london

df_london.major_category.value_counts().plot(kind='bar', color='steelblue')
# Out:
# <AxesSubplot:>

# %%
# Menghitung banyak kasus berdasarkan major_category pada dataframe london

df_london.major_category.value_counts()
# Out:
# Theft and Handling             5871
# Violence Against the Person    4736
# Criminal Damage                2979
# Drugs                          1807
# Burglary                       1566
# Robbery                        1399
# Other Notifiable Offences      1149
# Fraud or Forgery                344
# Sexual Offences                 149
# Name: major_category, dtype: int64

# %%
# Memvisualisasikan banyak kasus berdasrkan major_category pada dataframe london

df_london.major_category.value_counts().plot(kind='bar', color='steelblue')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Horizontal Bar Plot

# %%
# Menghitung banyak kasus berdasrkan minor_category pada dataframe london

df_london.major_category.value_counts().plot(kind='barh', color='steelblue')
# Out:
# <AxesSubplot:>

# %%
# Memvisualisasikan banyak kasus berdasrkan minor_category pada dataframe london

df_london.minor_category.value_counts().plot(kind='barh', color='steelblue')
# Out:
# <AxesSubplot:>

# %%
# Menghitung banyak kasus berdasarkan minor_category pada dataframe london

df_london.minor_category.value_counts()
# Out:
# Possession Of Drugs                       819
# Assault with Injury                       817
# Harassment                                810
# Theft/Taking of Pedal Cycle               807
# Burglary in a Dwelling                    804
# Other Notifiable                          784
# Wounding/GBH                              782
# Common Assault                            777
# Theft/Taking Of Motor Vehicle             774
# Other Theft                               770
# Other Criminal Damage                     765
# Personal Property                         764
# Burglary in Other Buildings               762
# Motor Vehicle Interference & Tampering    760
# Other Theft Person                        758
# Criminal Damage To Dwelling               749
# Drug Trafficking                          746
# Other violence                            743
# Criminal Damage To Other Building         741
# Criminal Damage To Motor Vehicle          724
# Theft From Motor Vehicle                  714
# Offensive Weapon                          686
# Handling Stolen Goods                     647
# Theft From Shops                          641
# Business Property                         635
# Going Equipped                            365
# Other Drugs                               242
# Counted per Victim                        196
# Other Fraud & Forgery                     148
# Murder                                    121
# Other Sexual                              110
# Rape                                       39
# Name: minor_category, dtype: int64

# %% [markdown]
# Informasi
#
# * Theft and Handling menjadi major category paling besar sebanyak 5871 kasus
# * Sexual Offences menjadi major category paling kecil sebanyak 149 kasus
# * Possession Of Drugs menjadi minor category paling besar sebanyak 819 kasus
# * Rape menjadi minor category paling kecil sebanyak 39 kasus

# %% [markdown]
# ### Pie Charts
#
# * Mengimplementasikan Pie Chart Menggunakan Matplotlib Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik

# %%
# Mendeklarasikan variable lables yang menyimpan nilai dari major category

lables=df_london['major_category'].unique()

# %%
# Mendeklarasikan variable sizes yang menyimpan ukuran masing-masing major category

sizes=df_london.groupby(['major_category']).size()

# %%
# Mendeklarasikan variable colors yang menyimpan warna

colors=['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink',
          'lightsteelblue','cornflowerblue','paleturquoise']

# %%
plt.figure(figsize=(20,10)) # Mengatur ukuran visualisasi
ax = plt.axes()
ax.set_facecolor("lightblue") # Memberi warna background
plt.title('Persentase Kejadian Kriminal Berdasarkan Major Category')
ab=plt.pie(sizes, labels=lables, colors=colors, startangle=90,autopct='%1.1f%%', textprops={'fontsize': 13,'color':'black'})
plt.show()

# %%
# Mendeklarasikan variable lables_b yang menyimpan nilai dari tahun

lables_b=df_london['year'].unique()

# %%
# Mendeklarasikan variable size_b yang menyimpan ukuran masing-masing tahun

size_b=df_london.groupby(['year']).size()

# %%
# Mendeklarasikan variable colors_b yang menyimpan warna

colors_b=['darkturquoise','lightskyblue','teal','turquoise', 'deepskyblue','steelblue',
        'lightsteelblue','cornflowerblue','paleturquoise']

# %%
plt.figure(figsize=(20,10)) # Mengatur ukuran visualisasi
ax = plt.axes()
ax.set_facecolor("lightblue") # Memberi warna background
plt.title('Persentase Kejadian Kriminal Berdasarkan Tahun')
ab=plt.pie(size_b, labels=lables_b, colors=colors_b, startangle=90,autopct='%1.1f%%', textprops={'fontsize': 14,'color':'darkblue'})
plt.show()

# %% [markdown]
# Informasi
#
# * Other Notifiable Offences menjadi major category paling besar sebanyak 29.4%
# * Fraud or Forgery menjadi major category paling kecil sebanyak 0.7%
# * Tahun 2008 dan 2015 menjadi tahun yang paling sering terjadi kejadian kriminal yakni sebesar 11.4%
# * Tahun 2011 dan 2014 menjadi tahun yang paling jarang terjadi kejadian kriminal sebesar 10.8%

# %% [markdown]
# ### Box Plots
#
# * Mengimplementasikan Box Plots Menggunakan Matplotlib Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik

# %%
df_london.lsoa_code.value_counts().plot(kind='box', color='darkblue')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Informasi
#
# * Berdasrkan lsoa_code, mayoritas terjadi 3-6 kasus per lsoa_code

# %% [markdown]
# ### Scatter Plots
#
# * Mengimplementasikan Scatter Plots Menggunakan Matplotlib Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik

# %%
# Mendeklarasikan variabel year2015 yang berisi kejadian kriminal pada tahun 2015

year_2015=df_london.loc[df_london['year'] == 2015]

# %%
# Mendeklarasikan variabel month yang berisi bulan

months=year_2015['month'].unique()

# %%
# mengurutkan bulan

months.sort()

# %%
# menjumlahkan kejadian per bulan

sum_month=year_2015.groupby(['month']).sum()

# %%
# Mendeklarasikan variabel values berisi nilai value yang dikonversi ke numpy array

values=sum_month['value'].to_numpy()

# %%
# Mendeklarasikan nama-nama bulan kedalam list

months_name=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# %%
print("Jumlah Kejadian Kriminal setiap bulan pada tahun 2015")
print(months_name)
print(values)
# Out:
# Jumlah Kejadian Kriminal setiap bulan pada tahun 2015
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# [ 65  89  82  70 124 111  76  64  58  75  81  87]

# %%
# membuat array dengan panjang sesuai bulan

n1 = np.arange(len(months))
xrange=range(1,13)

# %%
plt.figure(figsize=(10,5)) # mengatur ukuran plot
ax = plt.axes()
ax.set_facecolor("gold") # mengatur warna background
plt.scatter(xrange,values,s=250,color='red',cmap='viridis',alpha=1) # memvisualisasikan data menggunakan scatter
plt.title("Jumlah kejadian kriminal setiap bulan pada tahun 2015", color='red') # menambahkan judul
plt.xlabel('Bulan',color='red') # menambahkan x-label
plt.ylabel('Banyak Kasus',color='red') # menambahkan y-label
plt.xticks(n1,months_name) # mencetak nama bulan
plt.xticks(color='red') # mencetak xticks dan memberi warna 
plt.yticks(color='red') # mencetak yticks dan memberi warna
# Out:
# (array([ 50.,  60.,  70.,  80.,  90., 100., 110., 120., 130.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# Informasi
#
# * Pada tahun 2015, Bulan Juni menjadi bulan yang paling sering terjadi kejadian kriminal dengan 120 kasus
# * Pada tahun 2015, Bulan Oktober menjadi bulan yang paling jarang terjadi kejadian kriminal dengan kurang dari 60 kasus

# %% [markdown]
# ### Visualizing Data Using Matplotlib

# %%
# Import matplotlib

# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches #needed for waffle Charts

mpl.style.use('ggplot') # optional : for ggplot like style

# check for latest version of matplotlib
print('Matplotlib version: ', mpl.__version__)
# Out:
# Matplotlib version:  3.5.1

# %% [markdown]
# ### Word Clouds
#
# * Mengimplementasikan Word Clouds Menggunakan 'Word Clouds' Library Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik

# %%
# install wordcloud
# !conda install -c conda-forge wordcloud --yes

# !pip install wordcloud

# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS
from PIL import Image # converting images into arrays

print('WordCloud is installed and imported')
# Out:
# Requirement already satisfied: wordcloud in c:\users\agung\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\agung\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\agung\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pillow in c:\users\agung\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\agung\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\agung\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\agung\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\agung\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\agung\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\agung\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\agung\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WordCloud is installed and imported

# %%
# open the file and read it into a variable london12000
london_20000 = open('london_crime_20000.csv', 'r').read()

print('File downloaded and saved!')
# Out:
# File downloaded and saved!

# %%
# menggunakan set untuk menghapus stopword yang berlebihan

stopwords = set(STOPWORDS)

# %%
# instantiate a word cloud object
london_wc = WordCloud(
background_color='white',
max_words=2500, # mengambil 2500 kata pertama saja
stopwords=stopwords)

# generate the word cloud
london_wc.generate(london_20000)

# %%
# memvisualisasikan word cloud

plt.imshow(london_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# mengubah ukuran cloud
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

# memvisualisasikan word cloud
plt.imshow(london_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# save mask to london_mask
london_mask = np.array(Image.open('london_mask.png'))

print('Image downloaded and saved')
# Out:
# Image downloaded and saved

# %%
# mengubah ukuran cloud
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

# memvisualisasikan word cloud
plt.imshow(london_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# instantiate a word cloud object
london_wc = WordCloud(
background_color='white',
max_words=2500, # mengambil 3000 kata pertama saja
mask=london_mask,
stopwords=stopwords)

# generate the word cloud
london_wc.generate(london_20000)

# mengubah ukuran cloud
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

# memvisualisasikan word cloud
plt.imshow(london_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Informasi
#
# * Kata Criminal Damage, Motor Vehicle, Handling Theft, dan Damage Criminal merupakan kata yang paling sering muncul dalam 2500 kata pertama

# %% [markdown]
# ### Folium
#
# * Mengimplementasikan London Maps Menggunakan Folium

# %%
# Menginstall Folium
# !pip install folium
import folium

print('Folium installed and imported!')
# Out:
# Requirement already satisfied: folium in c:\users\agung\anaconda3\lib\site-packages (0.12.1.post1)
# Requirement already satisfied: numpy in c:\users\agung\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: jinja2>=2.9 in c:\users\agung\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: branca>=0.3.0 in c:\users\agung\anaconda3\lib\site-packages (from folium) (0.5.0)
# Requirement already satisfied: requests in c:\users\agung\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\agung\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\agung\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\agung\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agung\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\agung\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Folium installed and imported!

# %%
# Mendefinisikan Peta Dunia
world_map = folium.Map()

# Menampilkan Peta Dunia
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68d93101eef1defe850780348bbaff98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68d93101eef1defe850780348bbaff98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_68d93101eef1defe850780348bbaff98 = L.map(
#                 &quot;map_68d93101eef1defe850780348bbaff98&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e4793a1b6f657d207c0833e0ea520dc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_68d93101eef1defe850780348bbaff98);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Mendefinisikan peta dunia terpusat disekitar London dengan zoom level 15
world_map = folium.Map(location=[51.5072,-0.1180], zoom_start=15)

# Menampilkan world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9cb3135d98edb733f813d60283b85f15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9cb3135d98edb733f813d60283b85f15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9cb3135d98edb733f813d60283b85f15 = L.map(
#                 &quot;map_9cb3135d98edb733f813d60283b85f15&quot;,
#                 {
#                     center: [51.5072, -0.118],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13e6ae8734638cc7c847ab4c06768724 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9cb3135d98edb733f813d60283b85f15);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Stamen Toner Maps

# %%
# Membuat peta Stamen Toner dunia yang berpusat di sekitar London
world_map = folium.Map(location=[51.5072,-0.1180], zoom_start=13, tiles='Stamen Toner')

# Melihat peta
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b2f09b035be0b16afb677a48ba5930a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b2f09b035be0b16afb677a48ba5930a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9b2f09b035be0b16afb677a48ba5930a = L.map(
#                 &quot;map_9b2f09b035be0b16afb677a48ba5930a&quot;,
#                 {
#                     center: [51.5072, -0.118],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bcee9ac733f3e94eec39c74b2224fa9 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9b2f09b035be0b16afb677a48ba5930a);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Stamen Terrain Maps

# %%
# Membuat peta Stamen Terrain dunia yang berpusat di sekitar London
world_map = folium.Map(location=[51.5072,-0.1180], zoom_start=13, tiles='Stamen Terrain')

# Melihat Peta
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5a72423e75b6f85ebe18a064484ed31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5a72423e75b6f85ebe18a064484ed31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b5a72423e75b6f85ebe18a064484ed31 = L.map(
#                 &quot;map_b5a72423e75b6f85ebe18a064484ed31&quot;,
#                 {
#                     center: [51.5072, -0.118],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f41f37c59f7961bbfeff04ba38d9cc86 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b5a72423e75b6f85ebe18a064484ed31);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Choropleth Maps
#
# * Mengimplementasikan London Maps Menggunakan Choropleth Maps

# %%
import folium # Mengimpor folium

df_b=df_london[['borough','value']]
world_geo = r'https://raw.githubusercontent.com/radoi90/housequest-data/master/london_boroughs.geojson' 
world_map=folium.Map(location=[51.5072,-0.1180],zoom_start=10,tiles = 'Stamen Terrain')

# %%
# Mencetak choropleth

world_map.choropleth(
    geo_data=world_geo,
    name='choropleth',
    data=df_b,
    columns=['borough', 'value'],
    key_on='feature.properties.name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Tingkat kejadian kriminal di Wilayah London'
    )

world_map.save('LondonCrime.html') # menyimpan hasil dalam bentuk gambar ke direktori
display(world_map) # menampilkan map
# Out:
# c:\Users\Agung\anaconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8108ba9702783e01bc9177828a7aac3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8108ba9702783e01bc9177828a7aac3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b8108ba9702783e01bc9177828a7aac3 = L.map(
#                 &quot;map_b8108ba9702783e01bc9177828a7aac3&quot;,
#                 {
#                     center: [51.5072, -0.118],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c3b6e13a7ecf39d95da984d1508ff27 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b8108ba9702783e01bc9177828a7aac3);
#
#
#             var choropleth_598c9c4dc2ee0842165a319ebe856804 = L.featureGroup(
#                 {}
#             ).addTo(map_b8108ba9702783e01bc9177828a7aac3);
#
#
#         function geo_json_0e232f211137a24b43df7daf7710a4b6_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Barnet&quot;: case &quot;Enfield&quot;: case &quot;Kingston upon Thames&quot;: case &quot;Lewisham&quot;: case &quot;Westminster&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Kensington and Chelsea&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_0e232f211137a24b43df7daf7710a4b6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0e232f211137a24b43df7daf7710a4b6 = L.geoJson(null, {
#                 onEachFeature: geo_json_0e232f211137a24b43df7daf7710a4b6_onEachFeature,
#
#                 style: geo_json_0e232f211137a24b43df7daf7710a4b6_styler,
#         });
#
#         function geo_json_0e232f211137a24b43df7daf7710a4b6_add (data) {
#             geo_json_0e232f211137a24b43df7daf7710a4b6
#                 .addData(data)
#                 .addTo(choropleth_598c9c4dc2ee0842165a319ebe856804);
#         }
#             geo_json_0e232f211137a24b43df7daf7710a4b6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[0.1885882, 51.5538749], [0.1883107494386028, 51.554023919399114], [0.1883052, 51.5540269], [0.1881102, 51.5540519], [0.1879652, 51.55409900000001], [0.18790820000000003, 51.554176], [0.18796320000000002, 51.554243], [0.18806220000000004, 51.55427900000001], [0.18812019999999996, 51.554375], [0.18803619999999996, 51.554446], [0.1878722, 51.554473], [0.1876942, 51.554477], [0.18761319999999998, 51.554547], [0.1875692, 51.554662], [0.18763520000000003, 51.554738], [0.1877402, 51.55479499999999], [0.18778820000000002, 51.554871000000006], [0.1876902, 51.555053], [0.18765520000000002, 51.55515], [0.1875422, 51.555245], [0.18744919999999998, 51.55537], [0.18725819999999999, 51.555502999999995], [0.1870832, 51.555566], [0.18704120000000002, 51.555647], [0.18702519999999997, 51.555763], [0.18697219999999998, 51.555803], [0.1869102, 51.555842], [0.1867604, 51.5558685], [0.1865362, 51.555907999999995], [0.18642219999999998, 51.555978], [0.18631019999999998, 51.556163], [0.1860362, 51.55626900000001], [0.1859512, 51.556359], [0.1857502, 51.556404], [0.1855292, 51.556429], [0.1850082, 51.556394], [0.18482320000000002, 51.556447], [0.1848272, 51.55652599999999], [0.18481520000000004, 51.5566519], [0.18487319999999996, 51.5566519], [0.18501420000000002, 51.5566759], [0.18509419999999996, 51.5567519], [0.18510020000000005, 51.5568399], [0.1849542, 51.55689089999999], [0.1848342, 51.5570609], [0.1848582, 51.5571589], [0.1849092, 51.5572299], [0.1848592, 51.5573159], [0.1847572, 51.5574449], [0.1845912, 51.55754890000001], [0.1844882, 51.557657899999995], [0.1844832, 51.5576949], [0.1844882, 51.5577779], [0.18449820000000003, 51.55782490000001], [0.1845312, 51.5579129], [0.1844822, 51.5579809], [0.1845272, 51.5580969], [0.18459520000000001, 51.55819590000001], [0.1846512, 51.5583169], [0.1846282, 51.5584299], [0.1846632, 51.5585049], [0.1846612, 51.5585569], [0.18463020000000002, 51.5587139], [0.18466319999999997, 51.558743899999996], [0.1848552, 51.558886900000005], [0.

# %% [markdown]
# Informasi
#
# * Berdasarkan Peta, Daerah kensington dan bayswater merupakan daerah yang paling rawan terjadi kejadian kriminal

# %% [markdown]
# ### Kesimpulan
# * Berdasarkan Major Category, Kasus Theft and Handling paling sering terjadi di London.
# * Berdasarkan Minor Category, Kasus Possesion of Drugs paling sering terjadi di London.
# * Tahun 2008 dan 2015 menjadi tahun paling banyak terjadi kasus kriminal dengan 11.4%.
# * Pada tahun 2015, Bulan Juni menjadi bulan yang paling sering terjadi kejadian kriminal dengan 120 kasus.
# * Pada tahun 2015, Bulan Oktober menjadi bulan yang paling jarang terjadi kejadian kriminal dengan kurang dari 60 kasus.
